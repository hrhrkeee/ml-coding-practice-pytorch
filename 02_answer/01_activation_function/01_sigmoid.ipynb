# %%
import numpy as np
from notebook_setup import test

@test("01_activation_function.test_01_sigmoid", filter_name="forward")
def sigmoid_forward(x: np.ndarray) -> np.ndarray:
    """
    Parameters
    ----------
    x : np.ndarray : shape (N, ...)

    Returns
    -------
    result : np.ndarray : shape (N, ...)
    """
    result = None

    # ここにコードを記述
    # ---------------------------------------- #
    result = 1.0 / (1.0 + np.exp(-x))
    # ---------------------------------------- #

    return result

# %%
import numpy as np
from notebook_setup import test

@test("01_activation_function.test_01_sigmoid", filter_name="backward")
def sigmoid_backward(x: np.ndarray, grad_output: np.ndarray) -> np.ndarray:
    """
    Parameters
    ----------
    x           : np.ndarray : shape (N, ...)
    grad_output : np.ndarray : shape (N, ...)

    Returns
    -------
    result : np.ndarray : shape (N, ...)
    """
    result = None

    # ここにコードを記述
    # ---------------------------------------- #
    sigmoid_x = 1.0 / (1.0 + np.exp(-x))
    result = grad_output * sigmoid_x * (1.0 - sigmoid_x)
    # ---------------------------------------- #

    return result
