# %%
import numpy as np

def tanh_forward(x: np.ndarray) -> np.ndarray:
    """
    Parameters
    ----------
    x : np.ndarray : shape (N, ...)

    Returns
    -------
    result : np.ndarray : shape (N, ...)
    """
    result = None

    # ここにコードを記述
    # ---------------------------------------- #
    
    # ---------------------------------------- #

    return result

from notebook_setup import run_test
run_test("01_activation_function.test_03_tanh", filter_name="forward", tanh_forward=tanh_forward)

# %%
import numpy as np

def tanh_backward(x: np.ndarray, grad_output: np.ndarray) -> np.ndarray:
    """
    Parameters
    ----------
    x           : np.ndarray : shape (N, ...)
    grad_output : np.ndarray : shape (N, ...)

    Returns
    -------
    result : np.ndarray : shape (N, ...)
    """
    result = None

    # ここにコードを記述
    # ---------------------------------------- #
    
    # ---------------------------------------- #

    return result

from notebook_setup import run_test
run_test("01_activation_function.test_03_tanh", filter_name="backward", tanh_backward=tanh_backward)
