# %%
import numpy as np

def relu_forward(x: np.ndarray) -> np.ndarray:
    """
    Parameters
    ----------
    x : np.ndarray : shape (N, ...)

    Returns
    -------
    result : np.ndarray : shape (N, ...)
    """
    result = None

    # ここにコードを記述
    # ---------------------------------------- #
    
    # ---------------------------------------- #

    return result

from notebook_setup import run_test
run_test("01_activation_function.test_02_relu", filter_name="forward", relu_forward=relu_forward)

# %%
import numpy as np

def relu_backward(x: np.ndarray, grad_output: np.ndarray) -> np.ndarray:
    """
    Parameters
    ----------
    x           : np.ndarray : shape (N, ...)
    grad_output : np.ndarray : shape (N, ...)

    Returns
    -------
    result : np.ndarray : shape (N, ...)
    """
    result = None

    # ここにコードを記述
    # ---------------------------------------- #
    
    # ---------------------------------------- #

    return result

from notebook_setup import run_test
run_test("01_activation_function.test_02_relu", filter_name="backward", relu_backward=relu_backward)
