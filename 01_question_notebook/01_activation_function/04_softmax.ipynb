# %%
import numpy as np

def softmax_forward(x: np.ndarray) -> np.ndarray:
    """
    Parameters
    ----------
    x : np.ndarray : shape (N, C)

    Returns
    -------
    result : np.ndarray : shape (N, C)
    """
    result = None

    # ここにコードを記述
    # ---------------------------------------- #
    
    # ---------------------------------------- #

    return result

from notebook_setup import run_test
run_test("01_activation_function.test_04_softmax", filter_name="forward", softmax_forward=softmax_forward)
# Out:
# ----------------------------------------
# Running tests for: 01_activation_function.test_04_softmax
# ----------------------------------------
#   test_softmax_forward_value PASS
#
#  => Result: PASS
# ----------------------------------------

# %%
import numpy as np

def softmax_backward(x: np.ndarray, grad_output: np.ndarray) -> np.ndarray:
    """
    Parameters
    ----------
    x           : np.ndarray : shape (N, C)
    grad_output : np.ndarray : shape (N, C)

    Returns
    -------
    result : np.ndarray : shape (N, C)
    """
    result = None

    # ここにコードを記述
    # ---------------------------------------- #
    
    # ---------------------------------------- #

    return result

from notebook_setup import run_test
run_test("01_activation_function.test_04_softmax", filter_name="backward", softmax_backward=softmax_backward)
