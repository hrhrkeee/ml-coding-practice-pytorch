# %% [markdown]
# # 01. Matrix Multiplication - 行列積
#
# 行列の積（Matrix Multiplication）を実装します。
#
# ## 定義
#
# 行列 $A \in \mathbb{R}^{m \times n}$ と $B \in \mathbb{R}^{n \times p}$ の積:
#
# $$
# C_{ij} = \sum_{k=1}^{n} A_{ik} B_{kj}
# $$

# %%
import numpy as np
from notebook_setup import test

@test("05_matrix_operations.test_01_matrix_multiply", filter_name="multiply")
def matrix_multiply(A: np.ndarray, B: np.ndarray) -> np.ndarray:
    """
    行列積を計算
    
    Parameters
    ----------
    A : np.ndarray : shape (m, n)
    B : np.ndarray : shape (n, p)
    
    Returns
    -------
    C : np.ndarray : shape (m, p)
    """
    C = None
    
    # ここにコードを記述
    # ---------------------------------------- #

    # ---------------------------------------- #
    
    return C
