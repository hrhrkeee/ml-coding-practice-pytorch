# %% [markdown]
# # 02. Tensor Reshape - Tensorの形状変換
#
# Tensorの形状を変換する操作を実装します。
#
# ## Reshape
#
# Tensorの形状を変更します。
#
# ## Flatten
#
# 多次元Tensorを1次元に変換します。

# %%
import numpy as np
from notebook_setup import test

@test("03_tensor_operations.test_02_tensor_reshape", filter_name="reshape")
def reshape_tensor(x: np.ndarray, new_shape: tuple) -> np.ndarray:
    """
    Tensorの形状を変更
    
    Parameters
    ----------
    x         : np.ndarray - 入力Tensor
    new_shape : tuple      - 新しい形状
    
    Returns
    -------
    reshaped : np.ndarray
    """
    reshaped = None
    
    # ここにコードを記述
    # ---------------------------------------- #
    
    # ---------------------------------------- #
    
    return reshaped

# %%
import numpy as np
from notebook_setup import test

@test("03_tensor_operations.test_02_tensor_reshape", filter_name="flatten")
def flatten_tensor(x: np.ndarray) -> np.ndarray:
    """
    Tensorを1次元に変換
    
    Parameters
    ----------
    x : np.ndarray - 入力Tensor
    
    Returns
    -------
    flattened : np.ndarray : shape (N,)
    """
    flattened = None
    
    # ここにコードを記述
    # ---------------------------------------- #
    
    # ---------------------------------------- #
    
    return flattened
