# %% [markdown]
# # 01. Tensor Basics - 基本的なTensor操作
#
# PyTorchの基本的なTensor操作を実装します。
#
# ## 1. Tensor作成
#
# 指定された形状のランダムなTensorを作成します。
#
# ## 2. Tensor結合
#
# 複数のTensorを結合します（concatenate）。

# %%
import numpy as np
from notebook_setup import test

@test("03_tensor_operations.test_01_tensor_basics", filter_name="create")
def create_tensor(shape: tuple) -> np.ndarray:
    """
    指定された形状のランダムなTensorを作成
    
    Parameters
    ----------
    shape : tuple
        Tensorの形状
    
    Returns
    -------
    tensor : np.ndarray
    """
    tensor = None
    
    # ここにコードを記述
    # ---------------------------------------- #
    
    # ---------------------------------------- #
    
    return tensor

# %%
import numpy as np
from notebook_setup import test

@test("03_tensor_operations.test_01_tensor_basics", filter_name="concat")
def concat_tensors(tensors: list, axis: int = 0) -> np.ndarray:
    """
    複数のTensorを指定された軸に沿って結合
    
    Parameters
    ----------
    tensors : list of np.ndarray
        結合するTensorのリスト
    axis : int
        結合する軸
    
    Returns
    -------
    result : np.ndarray
    """
    result = None
    
    # ここにコードを記述
    # ---------------------------------------- #
    
    # ---------------------------------------- #
    
    return result
