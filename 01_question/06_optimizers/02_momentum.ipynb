# %% [markdown]
# # 02. Momentum SGD
#
# Momentum（運動量）を使った確率的勾配降下法を実装します。
#
# ## 更新式
#
# $$
# v_{t+1} = \mu v_t - \eta \nabla_{\theta} L(\theta_t)
# $$
#
# $$
# \theta_{t+1} = \theta_t + v_{t+1}
# $$
#
# ここで:
# - $v$: velocity（速度）
# - $\mu$: momentum係数（通常0.9）
# - $\eta$: 学習率

# %%
import numpy as np
from notebook_setup import test

@test("06_optimizers.test_02_momentum", filter_name="step")
def momentum_step(param: np.ndarray, grad: np.ndarray, velocity: np.ndarray, lr: float, momentum: float = 0.9) -> tuple:
    """
    Momentum SGDによるパラメータ更新
    
    Parameters
    ----------
    param    : np.ndarray - 現在のパラメータ
    grad     : np.ndarray - 勾配
    velocity : np.ndarray - 速度
    lr       : float      - 学習率
    momentum : float      - momentum係数
    
    Returns
    -------
    new_param    : np.ndarray - 更新後のパラメータ
    new_velocity : np.ndarray - 更新後の速度
    """
    new_param = None
    new_velocity = None
    
    # ここにコードを記述
    # ---------------------------------------- #
    
    # ---------------------------------------- #
    
    return new_param, new_velocity
