# %% [markdown]
# # 01. SGD (Stochastic Gradient Descent)
#
# 確率的勾配降下法（SGD）は、最も基本的な最適化アルゴリズムです。
#
# ## 更新式
#
# $$
# \theta_{t+1} = \theta_t - \eta \nabla_{\theta} L(\theta_t)
# $$
#
# ここで:
# - $\theta$: パラメータ
# - $\eta$: 学習率
# - $\nabla_{\theta} L$: 損失関数の勾配

# %%
import numpy as np
from notebook_setup import test

@test("06_optimizers.test_01_sgd", filter_name="step")
def sgd_step(param: np.ndarray, grad: np.ndarray, lr: float) -> np.ndarray:
    """
    SGDによるパラメータ更新
    
    Parameters
    ----------
    param : np.ndarray - 現在のパラメータ
    grad  : np.ndarray - 勾配
    lr    : float      - 学習率
    
    Returns
    -------
    new_param : np.ndarray - 更新後のパラメータ
    """
    new_param = None
    
    # ここにコードを記述
    # ---------------------------------------- #
    
    # ---------------------------------------- #
    
    return new_param
